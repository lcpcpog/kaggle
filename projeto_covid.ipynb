# %% [markdown]
# TLDR
#
# Dashboard: Google Data Studio (https://lookerstudio.google.com/reporting/cfc8e45e-774f-47c9-97a4-1fdb20378d46)
#
# Processamento: Kaggle Notebook (https://www.kaggle.com/code/lucaslcc/dashebords)
#
# Fontes:
#  Casos pela Universidade Johns Hopkins (https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports)
#
# Vacinação pela Universidade de Oxford (https://covid.ourworldindata.org/data/owid-covid-data.csv)

# %% [markdown]
# 📊 Projeto: Dashboard COVID-19 no Brasil
# 🦠 Introdução
# A COVID-19 é uma infecção respiratória aguda causada pelo coronavírus SARS-CoV-2. É uma doença com alta transmissibilidade, distribuição global e potencial de gerar quadros graves. Diante da sua rápida disseminação, a disponibilidade de dados atualizados sobre sua evolução temporal e geográfica tornou-se essencial para ações de prevenção e resposta.
#
# Este projeto tem como objetivo a construção de um dashboard interativo para visualização da evolução dos casos de COVID-19 e da vacinação no Brasil, utilizando dados públicos e confiáveis.

# %% [markdown]
# 📁 Fonte dos Dados
# 📍 Casos de COVID-19
# Os dados sobre casos confirmados são disponibilizados pelo Center for Systems Science and Engineering (CSSE) da Universidade Johns Hopkins.
# Esses dados:
#
# São atualizados diariamente desde janeiro de 2020
#
# Possuem granularidade por dia e por estado
#
# Estão disponíveis no site oficial e no GitHub do projeto:
#
# Website: https://systems.jhu.edu/research/public-health/ncov/
#
# Dados: https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports
#
# Campos processados no dataset de casos:
#
# date: data da observação
#
# state: estado brasileiro
#
# country: país
#
# population: população estimada
#
# confirmed: casos acumulados
#
# confirmed_1d: casos diários
#
# confirmed_moving_avg_7d: média móvel de 7 dias dos casos diários
#
# confirmed_moving_avg_7d_rate_14d: variação relativa da média móvel em relação a 14 dias atrás
#
# deaths: mortes acumuladas
#
# deaths_1d: mortes diárias
#
# deaths_moving_avg_7d: média móvel de 7 dias das mortes
#
# deaths_moving_avg_7d_rate_14d: variação relativa da média móvel de mortes
#
# month: mês da observação
#
# year: ano da observação
#
# 💉 Vacinação contra a COVID-19
# Os dados sobre vacinação são fornecidos pelo projeto Our World in Data (OWID) da Universidade de Oxford.
# Eles:
#
# Também são atualizados diariamente desde janeiro de 2020
#
# Possuem granularidade por país
#
# Estão disponíveis em:
#
# Website: https://ourworldindata.org/
#
# Dados: https://github.com/owid/covid-19-data/tree/master/public/data
#
# Campos processados no dataset de vacinação:
#
# date: data da observação
#
# country: país (Brasil)
#
# population: população estimada
#
# total: doses totais aplicadas
#
# one_shot: pessoas com ao menos uma dose
#
# one_shot_perc: percentual da população com uma dose
#
# two_shots: pessoas com duas doses
#
# two_shot_perc: percentual com duas doses
#
# three_shots: pessoas com três doses (reforço)
#
# three_shot_perc: percentual com três doses
#
# month: mês da observação
#
# year: ano da observação
#
# 🧪 Ferramentas Utilizadas
# Kaggle Notebooks para o pré-processamento dos dados
#
# Google Data Studio para construção do dashboard interativo
